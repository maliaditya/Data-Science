# %%
from bs4 import BeautifulSoup
import requests

# %%
source = requests.get('https://www.youtube.com/user/AddictedA1/videos').text

soup = BeautifulSoup(source, 'lxml')

# %%
#print(soup.prettify())
titles=[]
# for a in soup.find_all('h3', class_="yt-lockup-title"):
#     titles.append(soup.find_all('a', class_="yt-uix-sessionlink yt-uix-tile-link spf-link yt-ui-ellipsis yt-ui-ellipsis-2")['title'])

sumtitle =0
for anchor in soup.find_all('a', class_="yt-uix-sessionlink yt-uix-tile-link spf-link yt-ui-ellipsis yt-ui-ellipsis-2"):
    titles.append(anchor.text)
    sumtitle += 1

print(sumtitle)
# Out:
# 29

# %%
views = []
for anchor in soup.find_all('ul', class_="yt-lockup-meta-info"):
    views.append(anchor.text)
    
sum = 0
#print(views)
tokenized_view = []
for view in views:
    view_split = view.split()
    tokenized_view.append(view_split[0])
    sum += 1

#print(tokenized_view)
print(sum)
# Out:
# 29

# %%
Total_Revenue= []
for view in tokenized_view:
    Total_Revenue.append(int(int(view.replace(',', ''))/1000))

# %%
Total_Revenueinr=[]
for r in Total_Revenue:
    Total_Revenueinr.append(r*75)

# %%
import pandas as pd

Carrys_data = pd.DataFrame(
    {'Titles': titles,
     'Total_Views': tokenized_view,
     "Total_Revenue($)":Total_Revenue,
     "Total_Revenue(inr)": Total_Revenueinr
     
    })

Carrys_data
# Out:
#                                                Titles Total_Views  \
# 0                              YALGAAR....COMING SOON  26,394,125
# 1   STOP MAKING ASSUMPTIONS | YOUTUBE VS TIK TOK: ...  61,036,685
# 2                 WARRIOR - CARRYMINATI X Wily Frenzy   9,030,948
# 3                                      FILM THE FLARE  20,880,298
# 4            ARE YOU A VIRGIN? QNA 2020 | CARRYMINATI  12,487,378
# 5     BIG BOSS BIG BOSS BIG BOSS PART 2 | CARRYMINATI  27,061,957
# 6                 Zindagi - CARRYMINATI X Wily Frenzy  12,724,531
# 7                   LADKA LADKI AUR WOH | CARRYMINATI  16,169,394
# 8     NOT A DARING SHOW FT. WAKAR ZAQA  | CARRYMINATI  24,248,938
# 9               TALENTED PEOPLE OF VIGO | CARRYMINATI  17,147,291
# 10                     CUTE GIRLS PRANK | CARRYMINATI  14,733,998
# 11                    wildest parties by carry minati  16,941,233
# 12        I JUMPED OFF A PLANE | CARRYMINATI QnA 2019   8,539,086
# 13                TIKTOK EVOLUTION 2019 | CARRYMINATI  31,986,043
# 14                            SCHOOL TRIP OF THE YEAR  10,341,958
# 15                    TRIGGER - CARRYMINATI X VIBGYOR   9,334,227
# 16                       HEART BRAKEN KIDS OF TIK TOK  19,343,367
# 17       NO MORE SINGLE: VALENTINE SPECIAL FEAT ROCKY  27,901,689
# 18                             MY REAL AGE | QNA 2019   8,282,966
# 19                        Bye Pewdiepie | Carryminati  33,971,699
# 20                 WEDDING OF THE YEAR (I'M INVITED!)  20,683,876
# 21                                    Big Boss pART 1  18,320,167
# 22                     PUBG INDIA: LIFE BATTLE ROYALE  22,674,388
# 23                        INDIAN KID MEETS TOM CRUISE  17,703,250
# 24                             HOW TO GET MODERN LOVE  16,349,562
# 25                                  THE PERFECT BRIDE  14,200,512
# 26                                           QnA 2018   5,130,500
# 27                                       English U.S.  11,230,014
# 28                                   SANGEET BHOJPURI  14,885,922
#
#     Total_Revenue($)  Total_Revenue(inr)
# 0              26394             1979550
# 1              61036             4577700
# 2               9030              677250
# 3              20880             1566000
# 4              12487              936525
# 5              27061             2029575
# 6              12724              954300
# 7              16169             1212675
# 8              24248             1818600
# 9              17147             1286025
# 10             14733             1104975
# 11             16941             1270575
# 12              8539              640425
# 13             31986             2398950
# 14             10341              775575
# 15              9334              700050
# 16             19343             1450725
# 17             27901             2092575
# 18              8282              621150
# 19             33971             2547825
# 20             20683             1551225
# 21             18320             1374000
# 22             22674             1700550
# 23             17703             1327725
# 24             16349             1226175
# 25             14200             1065000
# 26              5130              384750
# 27             11230              842250
# 28             14885             1116375

# %%
Carrys_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Titles              29 non-null     object
#  1   Total_Views         29 non-null     object
#  2   Total_Revenue($)    29 non-null     int64
#  3   Total_Revenue(inr)  29 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.0+ KB

# %%
Total_views= []
for view in tokenized_view:
    Total_views.append(int(view.replace(',', '')))

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.bar(titles,students)
plt.show()

# %%
tokenized_view
